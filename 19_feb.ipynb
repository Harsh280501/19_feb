# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a micro-framework, meaning that it’s designed to perform a more limited role than a full-stack framework like Django. But, as you’ll find out, this isn’t necessarily a bad thing.
#
# Advantages
#
# Flask offers more flexibility
#
# Flask has more database support
#
# Flask is easier to use for smaller applications

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask
app = Flask(__name__)

@app.route('/')
def hello_world():
    return '<h1>Hello World</h1>'


if __name__ == "__main__":
    
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.6:5000
# Press CTRL+C to quit

# %% [markdown]
# ![image.png](attachment:af13014f-c215-49bf-8f1c-daf4bd1cd094.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing in Flask is a way to point out different functions that are written on the server side.
#
# App routing is used to navigate thorugh different web pages and it can be used as API's as well.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask
app = Flask(__name__)


@app.route('/')
def main():
    name = "ABC Corporation"
    location = "India"
    contact_number = "999-999-9999"
    return "<p>Name is {0}</p><p>Location is {1}</p> Contact_number is {2}".format(name,location,contact_number)


@app.route('/welcome')
def welcome():
    
    return "Welcome to ABC Corporation"



if __name__ == "__main__":
    
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.6:5000
# Press CTRL+C to quit
# 172.18.0.2 - - [27/Feb/2023 09:04:29] "GET / HTTP/1.1" 200 -
# 172.18.0.2 - - [27/Feb/2023 09:04:58] "GET /welcome HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:180cf055-4b61-40d2-bf0e-3caa7d5b20d4.png)

# %% [markdown]
# ![image.png](attachment:f1faf3b5-671e-4eb9-8530-8d9e882c9666.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# URL Building
#
# For building URLs in flask, we use the url_for() function. The name of the function is accepted as its first argument and any number of keyword arguments. The unknown variable parts in a website are then appended to the URL as query parameters

# %%
from flask import *  
   
app = Flask(__name__)  
  
@app.route('/admin')  
def admin():  
    return 'admin'  
  
@app.route('/librarion')  
def librarion():  
    return 'librarion'  
  
@app.route('/student')  
def student():  
    return 'student'  
  
@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  
    if name == 'librarion':  
        return redirect(url_for('librarion'))  
    if name == 'student':  
        return redirect(url_for('student'))  

if __name__ == "__main__":
    
    app.run(host = "0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.6:5000
# Press CTRL+C to quit
# 172.18.0.2 - - [27/Feb/2023 09:28:23] "GET /admin HTTP/1.1" 200 -
# 172.18.0.2 - - [27/Feb/2023 09:28:45] "GET /user/admin HTTP/1.1" 302 -
# 172.18.0.2 - - [27/Feb/2023 09:28:45] "GET /admin HTTP/1.1" 200 -
# 172.18.0.2 - - [27/Feb/2023 09:29:03] "GET /student HTTP/1.1" 200 -
# 172.18.0.2 - - [27/Feb/2023 09:29:19] "GET /user/librarion HTTP/1.1" 302 -
# 172.18.0.2 - - [27/Feb/2023 09:29:19] "GET /librarion HTTP/1.1" 200 -
# 172.18.0.2 - - [27/Feb/2023 09:29:28] "GET /admin HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:e43fbc0a-d24e-4005-bf84-f7fb23d82a5d.png)
